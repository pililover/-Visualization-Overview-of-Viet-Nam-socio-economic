# %% [markdown]
# # Preprocess data Nhập khẩu 2024

# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\ping\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.2.2)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Ping\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
columns = ["STT", "Nhóm/Mặt hàng chủ yếu", "ĐVT"]
categories = ["Số trong tháng báo cáo", "So với cùng kỳ"]
data = {category: pd.DataFrame() for category in categories}

# %%
for month in range(1, 13):
    file_path = f"data/xuat_nhap/nhap_khau_t{month}.xlsx"
    df = pd.read_excel(file_path, header=2)
    df = df.drop(columns=['Unnamed: 3', 'So với tháng trước (%)', 'Unnamed: 8', 
                          'Cộng dồn đến hết tháng báo cáo', 'Unnamed: 10', 'Unnamed: 11'],
                 errors='ignore')  
    df = df.iloc[3:-1]
    if month == 1:
        for category in categories:
            data[category] = df[columns].copy()
    col_index = 4 + 0
    for i, category in enumerate(categories):
        if col_index < len(df.columns):  
            data[category][f'Lượng Tháng {month}'] = df.iloc[:, col_index]
            data[category][f"Trị giá tháng {month}"] = df.iloc[:, col_index + 1]
        col_index = col_index + 2

# %%
output_file = "data/xuat_nhap/nhap_khau_2024.xlsx"
with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
    for sheet_name, df_sheet in data.items():
        df_sheet.to_excel(writer, sheet_name=sheet_name, index=False)

print(data)
# Out:
# {'Số trong tháng báo cáo':    STT                       Nhóm/Mặt hàng chủ yếu    ĐVT Lượng Tháng 1  \
# 3    1                               Hàng thủy sản    USD           NaN
# 4    2                         Sữa và sản phẩm sữa    USD           NaN
# 5    3                                Hàng rau quả    USD           NaN
# 6    4                                    Hạt điều    Tấn         91937
# 7    5                                      Lúa mì    Tấn        535465
# 8    6                                         Ngô    Tấn        976666
# 9    7                                   Đậu tương    Tấn        212228
# 10   8                        Dầu mỡ động thực vật    USD           NaN
# 11   9         Bánh kẹo và các sản phẩm từ ngũ cốc    USD           NaN
# 12  10                     Chế phẩm thực phẩm khác    USD           NaN
# 13  11              Thức ăn gia súc và nguyên liệu    USD           NaN
# 14  12                    Nguyên phụ liệu thuốc lá    USD           NaN
# 15  13                    Quặng và khoáng sản khác    Tấn       1798222
# 16  14                               Than các loại    Tấn       5089276
# 17  15                                     Dầu thô    Tấn       1347484
# 18  16                           Xăng dầu các loại    Tấn        737064
# 19  17                            Khí đốt hóa lỏng    Tấn        289018
# 20  18                     Sản phẩm khác từ dầu mỏ    USD           NaN
# 21  19                                    Hóa chất    USD           NaN
# 22  20                           Sản phẩm hóa chất    USD           NaN
# 23  21                   Nguyên phụ liệu dược phẩm    USD           NaN
# 24  22                                   Dược phẩm    USD           NaN
# 25  23                           Phân bón các loại    Tấn        411623
# 26  24      Chất thơm, mỹ phẩm và chế phẩm vệ sinh    USD           NaN
# 27  25                Thuốc trừ sâu và nguyên liệu    USD           NaN
# 28  26                        Chất dẻo nguyên liệu    Tấn        674388
# 29  27                        Sản phẩm từ chất dẻo    USD           NaN
# 30  28                                      Cao su    Tấn        188828
# 31  29                          Sản phẩm từ cao su    USD           NaN
# 32  30                           Gỗ và sản phẩm gỗ    USD           NaN
# 33  31                               Giấy các loại    Tấn        208647
# 34  32                            Sản phẩm từ giấy    USD           NaN
# 35  33                               Bông các loại    Tấn        146255
# 36  34                        Xơ, sợi dệt các loại    Tấn        106348
# 37  35                                Vải các loại    USD           NaN
# 38  36          Nguyên phụ liệu dệt, may, da, giày    USD           NaN
# 39  37      Thủy tinh và các sản phẩm từ thủy tinh    USD           NaN
# 40  38            Đá quý, kim loại quý và sản phẩm    USD           NaN
# 41  39                           Phế liệu sắt thép    Tấn        356078
# 42  40                           Sắt thép các loại    Tấn       1486502
# 43  41                        Sản phẩm từ sắt thép    USD           NaN
# 44  42                        Kim loại thường khác    Tấn        171662
# 45  43            Sản phẩm từ kim loại thường khác    USD           NaN
# 46  44  Máy vi tính, sản phẩm điện tử và linh kiện    USD           NaN
# 47  45             Hàng điện gia dụng và linh kiện    USD           NaN
# 48  46            Điện thoại các loại và linh kiện    USD           NaN
# 49  47         Máy ảnh, máy quay phim và linh kiện    USD           NaN
# 50  48   Máy móc, thiết bị, dụng cụ, phụ tùng khác    USD           NaN
# 51  49                    Dây điện và dây cáp điện    USD           NaN
# 52  50                  Ô tô nguyên chiếc các loại  Chiếc          6712
# 53  51                    Linh kiện, phụ tùng ô tô    USD           NaN
# 54  52               Xe máy và linh kiện, phụ tùng    USD           NaN
# 55  53        Phương tiện vận tải khác và phụ tùng    USD           NaN
# 56  54                               Hàng hóa khác    USD           NaN
#
#    Trị giá tháng 1 Lượng Tháng 2 Trị giá tháng 2 Lượng Tháng 3  \
# 3        244736410           NaN       158117572           NaN
# 4         81636356           NaN        64192668           NaN
# 5        216220191           NaN       120764176           NaN
# 6        104219096        131634       169569827        434579
# 7        156383877        502311       133617354        452368
# 8        249306347        929859       236924202        870717
# 9        122083763        127057        70956738        200752
# 10        79633001           NaN        64137166           NaN
# 11        45805730           NaN        28120604           NaN
# 12        90769663           NaN        79396810           NaN
# 13       397939417           NaN       341821507           NaN
# 14        10839349           NaN         7000310           NaN
# 15       228406571       1694597       206929606       2412691
# 16       669636315       4165319       610634714       5553407
# 17       828731603        902546       547211804       1094660
# 18       585307382        744975       616146046       1063707
# 19       200851548        214040       146523016        225606
# 20       195433960           NaN       192847076           NaN
# 21       678399276           NaN       560385432           NaN
# 22       668464447           NaN       440340683           NaN
# 23        39663476           NaN        26738787           NaN
# 24       340436782           NaN       256743477           NaN
# 25       137587259        286262        93401695        421652
# 26       104853800           NaN        94014240           NaN
# 27        64337187           NaN        46412502           NaN
# 28       917396726        463597       632529491        686310
# 29       738478055           NaN       482419141           NaN
# 30       248695066        105146       146002343        104809
# 31        88058196           NaN        59489509           NaN
# 32       219844704           NaN       122300375           NaN
# 33       186132502        131887       119295038        200509
# 34        82731036           NaN        47299123           NaN
# 35       289570323         97431       191103409        127753
# 36       222112831         61459       131248577        105436
# 37      1173872400           NaN       790138597           NaN
# 38       564954857           NaN       377561949           NaN
# 39       174542317           NaN       117278654           NaN
# 40        81638013           NaN        53699453           NaN
# 41       140940471        463450       176389338        460914
# 42      1058616836       1165117       823779742       1435818
# 43       520234240           NaN       335403249           NaN
# 44       720478978        131337       560489057        186475
# 45       265595257           NaN       162606572           NaN
# 46      8551893506           NaN      7083181628           NaN
# 47       187935832           NaN       167678685           NaN
# 48       889933832           NaN       589365997           NaN
# 49       216519012           NaN       152756470           NaN
# 50      3987830287           NaN      2582515140           NaN
# 51       270469218           NaN       183570788           NaN
# 52       139537549          9638       203223137         15857
# 53       342450419           NaN       260140638           NaN
# 54        48564630           NaN        29483489           NaN
# 55       120970776           NaN        80774811           NaN
# 56      1863177133           NaN      1354931529           NaN
#
#    Trị giá tháng 3 Lượng Tháng 4  ... Lượng Tháng 8 Trị giá tháng 8  \
# 3        215427363           NaN  ...           NaN       238362023
# 4         98273552           NaN  ...           NaN       108856845
# 5        155343851           NaN  ...           NaN       220351513
# 6        544324124        293326  ...        211225       283332382
# 7        127370346        807933  ...        269712        73247376
# 8        216068036        703808  ...       1189316       284435142
# 9        103491737        222610  ...        132031        66239793
# 10       106180371           NaN  ...           NaN       144915345
# 11        39523822           NaN  ...           NaN        56128734
# 12        98396813           NaN  ...           NaN       121629822
# 13       447566939           NaN  ...           NaN       453860896
# 14        10093090           NaN  ...           NaN        40547138
# 15       267326136       2214676  ...       2651958       279016385
# 16       689502656       5897141  ...       5379197       684860537
# 17       668730149       1090734  ...       1082368       684010763
# 18       889175400       1155587  ...        691085       514532482
# 19       153774126        255131  ...        326480       209514555
# 20       152394773           NaN  ...           NaN       158347106
# 21       696894526           NaN  ...           NaN       744701822
# 22       661868833           NaN  ...           NaN       666567681
# 23        40013295           NaN  ...           NaN        39748574
# 24       336893846           NaN  ...           NaN       349628251
# 25       120429650        494846  ...        448923       157532357
# 26       113017973           NaN  ...           NaN       133109072
# 27        81777677           NaN  ...           NaN        83658699
# 28       953940051        664336  ...        758996      1069576599
# 29       688789235           NaN  ...           NaN       782847540
# 30       168778597        104249  ...        188619       289029184
# 31        83402527           NaN  ...           NaN        98044393
# 32       193255767           NaN  ...           NaN       270704994
# 33       177407615        193180  ...        222422       195760110
# 34        85002135           NaN  ...           NaN       102753896
# 35       248671866        132859  ...        131433       253832363
# 36       220770478        104604  ...        114303       263812883
# 37      1184535164           NaN  ...           NaN      1239094767
# 38       610468283           NaN  ...           NaN       603714244
# 39       139303492           NaN  ...           NaN       108992937
# 40        66442369           NaN  ...           NaN        72875274
# 41       178059876        408998  ...        429547       161553063
# 42      1043717909       1282046  ...       1340998      1020440092
# 43       478537741           NaN  ...           NaN       559558020
# 44       760945772        165030  ...        187684       823616873
# 45       249579992           NaN  ...           NaN       285765379
# 46      8423484752           NaN  ...           NaN      9811965038
# 47       228782003           NaN  ...           NaN       140305108
# 48       797933448           NaN  ...           NaN       909038996
# 49       186256485           NaN  ...           NaN       186309329
# 50      3779124689           NaN  ...           NaN      4537047241
# 51       243006321           NaN  ...           NaN       330072399
# 52       330667671         11549  ...         15061       298813687
# 53       318246934           NaN  ...           NaN       425781861
# 54        45793222           NaN  ...           NaN        59878944
# 55       152792728           NaN  ...           NaN       128781684
# 56      1919797308           NaN  ...           NaN      1915260976
#
#    Lượng Tháng 9 Trị giá tháng 9 Lượng Tháng 10 Trị giá tháng 10  \
# 3            NaN       195520509            NaN        223665834
# 4            NaN        86183247            NaN         96393476
# 5            NaN       211911074            NaN        211765468
# 6         169864       243246431         141184        220724862
# 7         843823       226430606         482707        128209690
# 8        1152681       268425391        1548762        360642101
# 9         148004        71800114         222742        109836090
# 10           NaN       133438152            NaN        156992202
# 11           NaN        63823375            NaN         72813831
# 12           NaN       126314526            NaN        108859538
# 13           NaN       290377918            NaN        403717086
# 14           NaN        40992018            NaN         38949702
# 15       1629102       175853302        2388725        257491930
# 16       3971181       440722643        4339475        461176985
# 17       1168734       669255032        1096144        621729897
# 18        647398       437223266         938163        659007645
# 19        208338       136037689         269655        184148257
# 20           NaN       114332072            NaN        125595098
# 21           NaN       645080169            NaN        647690449
# 22           NaN       594868934            NaN        636205913
# 23           NaN        31635060            NaN         40580488
# 24           NaN       373924656            NaN        433420542
# 25        378158       140349453         515096        158660284
# 26           NaN       115913375            NaN        116065257
# 27           NaN        65040257            NaN         81403445
# 28        678691       936635931         732564       1006868064
# 29           NaN       727918881            NaN        749729436
# 30        157629       256918466         187321        320340698
# 31           NaN        88779319            NaN         94636481
# 32           NaN       234463878            NaN        235914933
# 33        216020       186608855         225154        196431361
# 34           NaN       105762059            NaN        105112588
# 35        119341       217834675         129883        232811247
# 36         96325       218101911         111363        237466312
# 37           NaN      1254140896            NaN       1316387571
# 38           NaN       653070683            NaN        631906454
# 39           NaN        94476714            NaN         99012340
# 40           NaN        79630902            NaN         84799981
# 41        308803       113934462         346153        122500320
# 42       1547165      1064543106        2412410       1508877331
# 43           NaN       525915025            NaN        567077173
# 44        171463       753142650         180657        819729289
# 45           NaN       255537912            NaN        259987460
# 46           NaN      9707688278            NaN       9409212378
# 47           NaN       148943176            NaN        159756856
# 48           NaN      1044739526            NaN       1071250576
# 49           NaN       174892200            NaN        191298594
# 50           NaN      4038482853            NaN       4295944755
# 51           NaN       265119616            NaN        300920507
# 52         18405       377776949          17706        374112694
# 53           NaN       447986951            NaN        545061799
# 54           NaN        56917693            NaN         60067600
# 55           NaN        94406189            NaN        223696037
# 56           NaN      1735384068            NaN       1823952596
#
#    Lượng Tháng 11 Trị giá tháng 11 Lượng Tháng 12 Trị giá tháng 12
# 3             NaN        241232692            NaN        306119172
# 4             NaN        102112936            NaN         99231052
# 5             NaN        250623086            NaN        304277033
# 6           84524        139392246         104546        184735768
# 7          354992        101465712         367333        100890792
# 8         1479583        352756483        1405743        343294691
# 9          163416         81167269         239148        110579486
# 10            NaN        135566463            NaN        142204237
# 11            NaN         72578716            NaN         75215541
# 12            NaN        121964200            NaN        123137642
# 13            NaN        420564858            NaN        456998003
# 14            NaN         67859287            NaN        105331836
# 15        2150728        221021647        2175033        233998600
# 16        4008716        411605308        5513483        593089551
# 17         863555        482351239        1163407        636960522
# 18         793955        564615360        1157605        836519217
# 19         264454        183658174         198268        138052771
# 20            NaN        119125126            NaN        183484127
# 21            NaN        643446920            NaN        710704765
# 22            NaN        661864913            NaN        699246125
# 23            NaN         39405869            NaN         53394508
# 24            NaN        307401437            NaN        518165974
# 25         474847        157049754         429891        124343250
# 26            NaN        128742693            NaN        132969644
# 27            NaN         75043808            NaN         97059719
# 28         742635       1028067165         821455       1115656038
# 29            NaN        792887494            NaN        833222659
# 30         194539        328641956         229668        380030584
# 31            NaN        102249246            NaN        105477075
# 32            NaN        231009914            NaN        257341223
# 33         225671        194465775         240230        209007037
# 34            NaN        100300181            NaN        104997168
# 35         131875        231984583         133383        233376725
# 36         111873        234167358         116879        238312729
# 37            NaN       1289475499            NaN       1330217118
# 38            NaN        604891983            NaN        643601847
# 39            NaN        104982235            NaN        120063745
# 40            NaN         85147753            NaN         87641377
# 41         448937        152310917         602245        210833561
# 42        1462514       1027784307        1554921       1080665390
# 43            NaN        583024172            NaN        609842971
# 44         183037        834857842         192402        902312960
# 45            NaN        292582854            NaN        308847820
# 46            NaN       9258234337            NaN       9322183671
# 47            NaN        163245783            NaN        208943470
# 48            NaN        969459986            NaN        973970092
# 49            NaN        178063968            NaN        195265139
# 50            NaN       4431094308            NaN       4685472325
# 51            NaN        318061004            NaN        348344743
# 52          17855        375902061          12881        303571525
# 53            NaN        474202741            NaN        478983075
# 54            NaN         55927222            NaN         60646829
# 55            NaN        147763670            NaN        260012285
# 56            NaN       1993843510            NaN       2086161708
#
# [54 rows x 27 columns], 'So với cùng kỳ':    STT                       Nhóm/Mặt hàng chủ yếu    ĐVT Lượng Tháng 1  \
# 3    1                               Hàng thủy sản    USD           NaN
# 4    2                         Sữa và sản phẩm sữa    USD           NaN
# 5    3                                Hàng rau quả    USD           NaN
# 6    4                                    Hạt điều    Tấn         -11.4
# 7    5                                      Lúa mì    Tấn         126.4
# 8    6                                         Ngô    Tấn          24.9
# 9    7                                   Đậu tương    Tấn         208.8
# 10   8                        Dầu mỡ động thực vật    USD           NaN
# 11   9         Bánh kẹo và các sản phẩm từ ngũ cốc    USD           NaN
# 12  10                     Chế phẩm thực phẩm khác    USD           NaN
# 13  11              Thức ăn gia súc và nguyên liệu    USD           NaN
# 14  12                    Nguyên phụ liệu thuốc lá    USD           NaN
# 15  13                    Quặng và khoáng sản khác    Tấn          21.6
# 16  14                               Than các loại    Tấn           209
# 17  15                                     Dầu thô    Tấn          24.8
# 18  16                           Xăng dầu các loại    Tấn         -26.9
# 19  17                            Khí đốt hóa lỏng    Tấn          10.3
# 20  18                     Sản phẩm khác từ dầu mỏ    USD           NaN
# 21  19                                    Hóa chất    USD           NaN
# 22  20                           Sản phẩm hóa chất    USD           NaN
# 23  21                   Nguyên phụ liệu dược phẩm    USD           NaN
# 24  22                                   Dược phẩm    USD           NaN
# 25  23                           Phân bón các loại    Tấn         196.3
# 26  24      Chất thơm, mỹ phẩm và chế phẩm vệ sinh    USD           NaN
# 27  25                Thuốc trừ sâu và nguyên liệu    USD           NaN
# 28  26                        Chất dẻo nguyên liệu    Tấn          74.5
# 29  27                        Sản phẩm từ chất dẻo    USD           NaN
# 30  28                                      Cao su    Tấn          32.7
# 31  29                          Sản phẩm từ cao su    USD           NaN
# 32  30                           Gỗ và sản phẩm gỗ    USD           NaN
# 33  31                               Giấy các loại    Tấn            70
# 34  32                            Sản phẩm từ giấy    USD           NaN
# 35  33                               Bông các loại    Tấn         109.2
# 36  34                        Xơ, sợi dệt các loại    Tấn          75.5
# 37  35                                Vải các loại    USD           NaN
# 38  36          Nguyên phụ liệu dệt, may, da, giày    USD           NaN
# 39  37      Thủy tinh và các sản phẩm từ thủy tinh    USD           NaN
# 40  38            Đá quý, kim loại quý và sản phẩm    USD           NaN
# 41  39                           Phế liệu sắt thép    Tấn          78.3
# 42  40                           Sắt thép các loại    Tấn         150.9
# 43  41                        Sản phẩm từ sắt thép    USD           NaN
# 44  42                        Kim loại thường khác    Tấn          42.7
# 45  43            Sản phẩm từ kim loại thường khác    USD           NaN
# 46  44  Máy vi tính, sản phẩm điện tử và linh kiện    USD           NaN
# 47  45             Hàng điện gia dụng và linh kiện    USD           NaN
# 48  46            Điện thoại các loại và linh kiện    USD           NaN
# 49  47         Máy ảnh, máy quay phim và linh kiện    USD           NaN
# 50  48   Máy móc, thiết bị, dụng cụ, phụ tùng khác    USD           NaN
# 51  49                    Dây điện và dây cáp điện    USD           NaN
# 52  50                  Ô tô nguyên chiếc các loại  Chiếc         -53.5
# 53  51                    Linh kiện, phụ tùng ô tô    USD           NaN
# 54  52               Xe máy và linh kiện, phụ tùng    USD           NaN
# 55  53        Phương tiện vận tải khác và phụ tùng    USD           NaN
# 56  54                               Hàng hóa khác    USD           NaN
#
#    Trị giá tháng 1 Lượng Tháng 2 Trị giá tháng 2 Lượng Tháng 3  \
# 3             31.1           NaN            -3.5           NaN
# 4             -8.2           NaN             -25           NaN
# 5             44.7           NaN            23.2           NaN
# 6            -19.1         -18.6           -24.3          13.2
# 7             80.7          67.2            26.4          22.8
# 8             -4.9          34.2             1.8            27
# 9            164.5          12.4            -9.5           8.3
# 10            16.9           NaN           -10.1           NaN
# 11            64.6           NaN             8.7           NaN
# 12             9.6           NaN            -6.3           NaN
# 13             5.7           NaN            -0.7           NaN
# 14           442.5           NaN           219.9           NaN
# 15            28.9            34            39.7            46
# 16             150          94.1            60.1          76.7
# 17            21.1          13.3            10.4          23.6
# 18           -35.5         -19.5           -26.3          -1.7
# 19            12.5          30.1            23.3          27.5
# 20            90.3           NaN            98.3           NaN
# 21            41.2           NaN              16           NaN
# 22            33.2           NaN             3.5           NaN
# 23            31.5           NaN               3           NaN
# 24            40.5           NaN            16.5           NaN
# 25           142.3         117.2            85.8          82.7
# 26            56.5           NaN            19.2           NaN
# 27            50.3           NaN             2.3           NaN
# 28            55.6          22.9            12.7          18.3
# 29              44           NaN            20.5           NaN
# 30            49.6          17.9            22.3          10.5
# 31            38.9           NaN            16.3           NaN
# 32              83           NaN            26.3           NaN
# 33            57.4          15.6            10.5             9
# 34            59.8           NaN            13.8           NaN
# 35            65.3          66.2            34.4          53.4
# 36            63.3            20            19.6          13.5
# 37            25.3           NaN            14.7           NaN
# 38              50           NaN            18.2           NaN
# 39            48.7           NaN            25.1           NaN
# 40            74.3           NaN           -16.3           NaN
# 41            83.9            20            20.9           3.4
# 42           101.3          84.6            56.9          49.2
# 43            35.6           NaN            18.7           NaN
# 44            28.4          20.4              10          19.6
# 45            71.1           NaN            41.2           NaN
# 46            30.3           NaN              25           NaN
# 47            93.1           NaN            32.4           NaN
# 48            12.1           NaN            12.1           NaN
# 49             7.3           NaN             4.9           NaN
# 50            45.6           NaN            17.4           NaN
# 51            67.6           NaN            37.1           NaN
# 52           -55.5         -38.9           -40.1         -23.4
# 53            11.9           NaN            -4.7           NaN
# 54            -7.3           NaN           -28.9           NaN
# 55               5           NaN            -0.4           NaN
# 56            44.4           NaN            15.9           NaN
#
#    Trị giá tháng 3 Lượng Tháng 4  ... Lượng Tháng 8 Trị giá tháng 8  \
# 3             -6.7           NaN  ...           NaN            -3.4
# 4            -22.8           NaN  ...           NaN            -6.9
# 5             17.6           NaN  ...           NaN              13
# 6              5.6          17.9  ...          -4.1            -2.2
# 7             -6.1          41.6  ...          20.5            -5.3
# 8             -4.9          23.9  ...          29.5             0.1
# 9            -14.4           3.5  ...           5.2           -13.9
# 10            -6.6           NaN  ...           NaN             4.8
# 11             3.9           NaN  ...           NaN            10.9
# 12           -12.6           NaN  ...           NaN               1
# 13             1.8           NaN  ...           NaN            -2.1
# 14           171.3           NaN  ...           NaN            46.2
# 15            47.6          32.4  ...          28.6            29.3
# 16            36.8          73.4  ...          32.7              16
# 17              21          21.1  ...          23.3            26.7
# 18            -6.5          13.6  ...          -4.3            -6.1
# 19            17.4          21.1  ...          26.7            35.6
# 20            62.6           NaN  ...           NaN            13.4
# 21             4.7           NaN  ...           NaN            12.2
# 22            -0.3           NaN  ...           NaN             2.4
# 23            -2.3           NaN  ...           NaN             5.1
# 24            15.5           NaN  ...           NaN            25.2
# 25              48          76.7  ...          43.6            36.9
# 26             8.7           NaN  ...           NaN            16.7
# 27            -0.3           NaN  ...           NaN            16.9
# 28             8.9          23.5  ...          23.4            18.8
# 29            15.4           NaN  ...           NaN            17.3
# 30            13.8             9  ...           7.8            24.5
# 31             8.8           NaN  ...           NaN            15.1
# 32            15.3           NaN  ...           NaN            26.6
# 33             4.6           8.9  ...            17            11.9
# 34            10.8           NaN  ...           NaN            17.4
# 35            26.7          37.7  ...          12.4             2.8
# 36            13.6          16.3  ...            20            25.9
# 37             5.5           NaN  ...           NaN            14.2
# 38            12.4           NaN  ...           NaN            17.1
# 39            18.1           NaN  ...           NaN             3.5
# 40           -23.2           NaN  ...           NaN           -11.4
# 41             2.2          -7.9  ...          13.1             7.9
# 42              29          42.4  ...          35.5            20.9
# 43            13.8           NaN  ...           NaN            23.2
# 44             7.4          14.5  ...          25.1            26.4
# 45            38.8           NaN  ...           NaN              49
# 46            24.2           NaN  ...           NaN            27.5
# 47            22.7           NaN  ...           NaN            18.8
# 48            19.8           NaN  ...           NaN            23.9
# 49             7.1           NaN  ...           NaN             7.3
# 50            12.6           NaN  ...           NaN            17.1
# 51            28.6           NaN  ...           NaN            32.6
# 52           -27.3         -19.5  ...          22.9             7.5
# 53            -7.9           NaN  ...           NaN              12
# 54           -24.6           NaN  ...           NaN            -2.9
# 55            16.5           NaN  ...           NaN              21
# 56              11           NaN  ...           NaN            13.3
#
#    Lượng Tháng 9 Trị giá tháng 9 Lượng Tháng 10 Trị giá tháng 10  \
# 3            NaN            -3.8            NaN             -2.4
# 4            NaN              -4            NaN             -2.5
# 5            NaN              14            NaN             15.7
# 6           -7.1            -2.2           -8.5             -1.1
# 7           37.9             8.6           34.9              7.1
# 8           24.3            -2.3           24.7             -0.4
# 9            8.3           -11.7           12.8             -8.1
# 10           NaN             2.4            NaN              2.8
# 11           NaN            11.9            NaN               12
# 12           NaN               6            NaN              5.4
# 13           NaN            -5.2            NaN             -5.8
# 14           NaN            42.3            NaN             35.7
# 15          26.7            25.2           29.9             27.5
# 16          32.2            14.9           31.1             13.1
# 17          31.9            32.5           26.6             23.1
# 18          -6.1           -10.7           -3.6            -10.1
# 19          24.7            33.8           25.6             34.3
# 20           NaN            12.4            NaN                3
# 21           NaN            10.6            NaN                9
# 22           NaN             1.4            NaN              1.2
# 23           NaN               4            NaN              5.4
# 24           NaN            24.2            NaN             26.9
# 25          32.3            29.7           31.1             27.1
# 26           NaN            17.1            NaN             16.5
# 27           NaN            13.5            NaN             12.8
# 28            22            18.1           21.3             17.9
# 29           NaN            16.5            NaN             16.6
# 30           7.4            25.9            8.9             30.1
# 31           NaN            15.5            NaN             16.2
# 32           NaN            26.2            NaN               27
# 33          16.9            12.4           16.9             13.2
# 34           NaN              18            NaN             19.9
# 35            12             2.3           12.8              2.7
# 36          18.6            24.7           18.2             24.4
# 37           NaN            14.3            NaN             14.7
# 38           NaN            18.3            NaN             19.3
# 39           NaN            -1.5            NaN               -6
# 40           NaN            -8.6            NaN             -5.1
# 41          11.9             7.9           11.5              7.7
# 42          31.6            18.9           38.2             23.2
# 43           NaN            22.3            NaN             21.6
# 44            23            25.1           22.3             24.9
# 45           NaN            46.5            NaN             43.4
# 46           NaN            25.8            NaN             23.7
# 47           NaN            19.6            NaN             19.9
# 48           NaN            21.9            NaN             18.8
# 49           NaN             4.3            NaN              2.6
# 50           NaN            16.6            NaN               17
# 51           NaN            30.4            NaN             30.9
# 52          32.7              16           37.5             19.1
# 53           NaN            14.9            NaN             17.5
# 54           NaN             0.7            NaN              3.5
# 55           NaN            22.8            NaN             39.7
# 56           NaN            12.2            NaN             12.2
#
#    Lượng Tháng 11 Trị giá tháng 11 Lượng Tháng 12 Trị giá tháng 12
# 3             NaN             -1.6            NaN              1.8
# 4             NaN             -2.9            NaN             -2.8
# 5             NaN             18.7            NaN             23.7
# 6           -10.2             -1.3            -10              0.7
# 7            34.8              8.3           22.5              1.2
# 8            32.9                7           28.9              6.1
# 9            19.6               -3           19.4             -3.6
# 10            NaN                4            NaN              4.5
# 11            NaN             13.1            NaN             17.4
# 12            NaN              7.9            NaN              8.6
# 13            NaN             -3.3            NaN               -1
# 14            NaN             27.8            NaN             27.2
# 15           27.9             24.3           24.6             20.5
# 16           25.8              7.6           24.9              6.6
# 17           24.2             19.4             20             14.6
# 18           -1.3             -8.8            3.6             -4.6
# 19           27.4             35.9             24             31.5
# 20            NaN              1.9            NaN              3.9
# 21            NaN              7.8            NaN              7.3
# 22            NaN              1.3            NaN              1.7
# 23            NaN                6            NaN              9.4
# 24            NaN             23.3            NaN             27.9
# 25           30.9             25.6           27.2               21
# 26            NaN             16.8            NaN             17.4
# 27            NaN             11.9            NaN               13
# 28           21.3             18.4           23.3             20.7
# 29            NaN             16.9            NaN             17.9
# 30            7.7             31.1            8.2             33.3
# 31            NaN             17.4            NaN             18.6
# 32            NaN             25.7            NaN             26.8
# 33           15.1             12.3             16             13.1
# 34            NaN             19.9            NaN             20.9
# 35           12.6              2.3           12.3              1.8
# 36           17.6               24           18.1             23.8
# 37            NaN             14.3            NaN             14.5
# 38            NaN             18.8            NaN             19.3
# 39            NaN             -8.3            NaN             -9.1
# 40            NaN             -1.7            NaN              1.5
# 41           11.9              7.5           14.3              9.9
# 42           32.9             20.3           32.9             20.6
# 43            NaN             20.7            NaN             21.6
# 44           21.4             24.8           21.1             25.3
# 45            NaN             41.2            NaN             41.7
# 46            NaN             22.4            NaN             21.7
# 47            NaN             19.7            NaN             21.1
# 48            NaN             17.6            NaN             18.9
# 49            NaN             -0.6            NaN             -1.8
# 50            NaN             17.3            NaN             17.6
# 51            NaN               31            NaN             32.5
# 52           44.4             24.7           45.8             27.6
# 53            NaN             17.2            NaN             18.3
# 54            NaN              4.5            NaN              5.2
# 55            NaN             36.8            NaN             44.7
# 56            NaN             12.2            NaN             12.8
#
# [54 rows x 27 columns]}
